# %% [markdown]
# La Notebook 05: Conclusiones es el cierre narrativo de tu trabajo técnico. A diferencia de las anteriores, esta notebook no se centra en la transformación de datos, sino en la síntesis de hallazgos y en responder a los objetivos de negocio planteados inicialmente
# .
# Esta etapa es fundamental para asegurar una coherencia total entre tus notebooks, el informe final en PDF y la aplicación de Streamlit
# . Aquí tienes la estructura recomendada basada en los requisitos de la cátedra:
# 1. Respuesta a Preguntas de Negocio (Markdown)
# Debés retomar las preguntas que te planteaste en la Notebook 01 y responderlas utilizando la evidencia generada en el EDA (Notebook 03) y el PCA (Notebook 04)
# .
# Ejemplo de redacción: "A partir del análisis bivariado, se confirma que los usuarios del Plan Premium tienen una mediana de consumo de X minutos, un Y% superior al Plan Básico. Esto evidencia que el modelo de escalabilidad de la plataforma es efectivo..."
# .
# 2. Síntesis de Resultados de PCA (Markdown)
# Explicá qué ganaste al reducir las dimensiones.
# Interpretación: Mencioná cómo los componentes principales (PC1, PC2) resumen el comportamiento del usuario (ej: nivel de actividad vs. fricción técnica) y por qué esto es más útil que mirar las variables aisladas
# .
# 3. Limitaciones y Mejoras Futuras (Markdown)
# Este es un requisito explícito de la rúbrica
# :
# Limitaciones: Factores que restringen tus conclusiones. Por ejemplo: "El dataset no cuenta con variables de ingresos económicos, lo que limita el análisis de la capacidad de pago para planes superiores"
# .
# Mejoras Futuras: Acciones para profundizar el proyecto. Por ejemplo: "En una etapa posterior, se recomienda aplicar algoritmos de Clustering sobre los componentes principales obtenidos para segmentar automáticamente a los usuarios"

# %% [markdown]
# 4. Bloque de Código: Resumen Final
# Aunque es una notebook de texto, podés incluir una celda que muestre los estadísticos clave del dataset final procesado para dejar constancia del estado del dato al cierre del proyecto.

# %%
import pandas as pd

# Carga del dataset final para el resumen de cierre
df = pd.read_csv('../data/processed/dataset_final.csv')

print("Resumen final de la base de usuarios procesada:")
display(df.describe().round(2))

# Cálculo de métrica de negocio final (ej: promedio de minutos global)
promedio_consumo = df['monthly_watch_time_mins'].mean()
print(f"\nConsumo promedio final tras limpieza: {promedio_consumo:.2f} minutos.")
# Out:
# Resumen final de la base de usuarios procesada:
#         user_id      age  monthly_watch_time_mins  customer_support_tickets
# count   7662.00  7662.00                  7662.00                   7662.00
# mean   14002.77    33.51                   795.54                      1.82
# std     2309.30    11.77                   495.77                     11.46
# min    10000.00     0.00                     0.00                      0.00
# 25%    11997.25    25.00                   492.00                      0.00
# 50%    14008.50    33.00                   759.55                      1.00
# 75%    15999.75    42.00                  1042.35                      1.00
# max    17999.00    80.00                  4193.70                    150.00
# Consumo promedio final tras limpieza: 795.54 minutos.
